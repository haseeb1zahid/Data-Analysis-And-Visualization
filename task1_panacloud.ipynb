# %%
import requests
import json

uri = requests.get('https://api.coinmarketcap.com/v1/ticker/').json()
# a = json.dumps(uri)
print(uri)
# Out:
# [{'id': 'bitcoin', 'name': 'Bitcoin', 'symbol': 'BTC', 'rank': '1', 'price_usd': '9607.37', 'price_btc': '1.0', '24h_volume_usd': '6148750000.0', 'market_cap_usd': '162502899128', 'available_supply': '16914400.0', 'total_supply': '16914400.0', 'max_supply': '21000000.0', 'percent_change_1h': '-0.1', 'percent_change_24h': '9.22', 'percent_change_7d': '-16.59', 'last_updated': '1520846065'}, {'id': 'ethereum', 'name': 'Ethereum', 'symbol': 'ETH', 'rank': '2', 'price_usd': '726.301', 'price_btc': '0.0760539', '24h_volume_usd': '1525140000.0', 'market_cap_usd': '71277461847.0', 'available_supply': '98137634.0', 'total_supply': '98137634.0', 'max_supply': None, 'percent_change_1h': '-0.08', 'percent_change_24h': '4.81', 'percent_change_7d': '-16.15', 'last_updated': '1520846051'}, {'id': 'ripple', 'name': 'Ripple', 'symbol': 'XRP', 'rank': '3', 'price_usd': '0.82211', 'price_btc': '0.00008609', '24h_volume_usd': '417858000.0', 'market_cap_usd': '32137888528.0', 'available_supply': '390919
# ...
